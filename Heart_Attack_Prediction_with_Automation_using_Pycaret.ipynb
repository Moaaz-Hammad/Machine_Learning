# %% [markdown]
# # Heart_Attack_Prediction_with_Automation_using_Pycaret

# %% [markdown]
# ## 1.Install and Import Dependencies

# %%
pip install pycaret pandas shap
# Out:
# Collecting pycaret
#   Using cached pycaret-3.0.4-py3-none-any.whl (484 kB)
# Requirement already satisfied: pandas in c:\users\moaaz\anaconda3\lib\site-packages (1.4.4)
# Collecting shap
#   Downloading shap-0.42.1-cp39-cp39-win_amd64.whl (462 kB)
#      -------------------------------------- 462.3/462.3 kB 2.1 MB/s eta 0:00:00
# Collecting schemdraw==0.15
#   Using cached schemdraw-0.15-py3-none-any.whl (106 kB)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (0.13.2)
# Collecting pyod>=1.0.8
#   Using cached pyod-1.1.0.tar.gz (153 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting yellowbrick>=1.4
#   Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# Collecting xxhash
#   Downloading xxhash-3.3.0-cp39-cp39-win_amd64.whl (29 kB)
# Collecting tbats>=1.1.3
#   Using cached tbats-1.1.3-py3-none-any.whl (44 kB)
# Requirement already satisfied: jinja2>=1.2 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (7.31.1)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (4.64.1)
# Collecting scikit-plot>=0.3.7
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting category-encoders>=2.4.0
#   Using cached category_encoders-2.6.1-py2.py3-none-any.whl (81 kB)
# Collecting deprecation>=2.1.0
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: scipy<2.0.0 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (1.9.1)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: cloudpickle in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (0.55.1)
# Requirement already satisfied: numpy<1.24,>=1.21 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (1.21.5)
# Collecting imbalanced-learn>=0.8.1
#   Using cached imbalanced_learn-0.11.0-py3-none-any.whl (235 kB)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (1.0.2)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Collecting pmdarima!=1.8.1,<3.0.0,>=1.8.0
#   Downloading pmdarima-2.0.3-cp39-cp39-win_amd64.whl (572 kB)
#      -------------------------------------- 572.7/572.7 kB 2.6 MB/s eta 0:00:00
# Collecting lightgbm>=3.0.0
#   Using cached lightgbm-4.0.0-py3-none-win_amd64.whl (1.3 MB)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (3.5.2)
# Collecting sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1
#   Using cached sktime-0.21.0-py3-none-any.whl (17.1 MB)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (5.5.0)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      -------------------------------------- 302.2/302.2 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.27.1 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (2.28.1)
# Collecting plotly-resampler>=0.8.3.1
#   Using cached plotly_resampler-0.9.1-py3-none-any.whl (73 kB)
# Collecting kaleido>=0.2.1
#   Using cached kaleido-0.2.1-py2.py3-none-win_amd64.whl (65.9 MB)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\moaaz\anaconda3\lib\site-packages (from pycaret) (5.9.0)
# Collecting importlib-metadata>=4.12.0
#   Using cached importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\moaaz\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\moaaz\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>20.9 in c:\users\moaaz\anaconda3\lib\site-packages (from shap) (21.3)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\moaaz\anaconda3\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\moaaz\anaconda3\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\moaaz\anaconda3\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.8.0)
# Requirement already satisfied: backcall in c:\users\moaaz\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\moaaz\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: pygments in c:\users\moaaz\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (2.11.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\moaaz\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\moaaz\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (63.4.1)
# Requirement already satisfied: pickleshare in c:\users\moaaz\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: colorama in c:\users\moaaz\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\moaaz\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: matplotlib-inline in c:\users\moaaz\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: decorator in c:\users\moaaz\anaconda3\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\moaaz\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\moaaz\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\moaaz\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\moaaz\anaconda3\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\moaaz\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\moaaz\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\moaaz\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\moaaz\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\moaaz\anaconda3\lib\site-packages (from matplotlib>=3.3.0->pycaret) (9.2.0)
# Requirement already satisfied: fastjsonschema in c:\users\moaaz\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\moaaz\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.16.0)
# Requirement already satisfied: jupyter_core in c:\users\moaaz\anaconda3\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.11.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\moaaz\anaconda3\lib\site-packages (from numba>=0.55.0->pycaret) (0.38.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\moaaz\anaconda3\lib\site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Collecting trace-updater>=0.0.8
#   Using cached trace_updater-0.0.9.1-py3-none-any.whl (185 kB)
# Collecting tsdownsample==0.1.2
#   Downloading tsdownsample-0.1.2-cp39-none-win_amd64.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 3.0 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.8.0
#   Downloading orjson-3.9.4-cp39-none-win_amd64.whl (200 kB)
#      -------------------------------------- 200.7/200.7 kB 4.1 MB/s eta 0:00:00
# Collecting dash<3.0.0,>=2.11.0
#   Using cached dash-2.11.1-py3-none-any.whl (10.4 MB)
# Requirement already satisfied: urllib3 in c:\users\moaaz\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.11)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\moaaz\anaconda3\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: six in c:\users\moaaz\anaconda3\lib\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\moaaz\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\moaaz\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\moaaz\anaconda3\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Collecting scikit-base<0.6.0
#   Using cached scikit_base-0.5.0-py3-none-any.whl (118 kB)
# Collecting deprecated>=1.2.13
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting ansi2html
#   Using cached ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\moaaz\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (4.3.0)
# Collecting dash-core-components==2.0.0
#   Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0
#   Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting retrying
#   Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: nest-asyncio in c:\users\moaaz\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.5)
# Requirement already satisfied: Werkzeug<2.3.0 in c:\users\moaaz\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.3)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in c:\users\moaaz\anaconda3\lib\site-packages (from dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.1.2)
# Collecting dash-html-components==2.0.0
#   Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\moaaz\anaconda3\lib\site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\moaaz\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: pyzmq>=17 in c:\users\moaaz\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\moaaz\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in c:\users\moaaz\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\moaaz\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\moaaz\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\moaaz\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\moaaz\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\moaaz\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.12)
# Requirement already satisfied: pywin32>=1.0 in c:\users\moaaz\anaconda3\lib\site-packages (from jupyter_core->nbformat>=4.2.0->pycaret) (302)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\moaaz\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\moaaz\anaconda3\lib\site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: entrypoints in c:\users\moaaz\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\moaaz\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\moaaz\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.13.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\moaaz\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.4)
# Requirement already satisfied: argon2-cffi in c:\users\moaaz\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: prometheus-client in c:\users\moaaz\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: testpath in c:\users\moaaz\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.6.0)
# Requirement already satisfied: bleach in c:\users\moaaz\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\moaaz\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\moaaz\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\moaaz\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\moaaz\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\moaaz\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\moaaz\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\moaaz\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\moaaz\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\moaaz\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\moaaz\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\moaaz\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\moaaz\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)
# Building wheels for collected packages: pyod
#   Building wheel for pyod (setup.py): started
#   Building wheel for pyod (setup.py): finished with status 'done'
#   Created wheel for pyod: filename=pyod-1.1.0-py3-none-any.whl size=185331 sha256=0e7deb1b2c42c9b95775ebb073e9db8a059505fa5db8e7f1e5f81d6823f4691a
#   Stored in directory: c:\users\moaaz\appdata\local\pip\cache\wheels\d7\21\ce\d0f4083609d89f6c4371a5ecb8c13636e7570abaed1e2473ce
# Successfully built pyod
# Installing collected packages: trace-updater, kaleido, dash-table, dash-html-components, dash-core-components, xxhash, tsdownsample, slicer, scikit-base, schemdraw, retrying, orjson, joblib, importlib-metadata, deprecated, ansi2html, lightgbm, deprecation, yellowbrick, sktime, shap, scikit-plot, pyod, imbalanced-learn, dash, pmdarima, plotly-resampler, category-encoders, tbats, pycaret
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
# Successfully installed ansi2html-1.8.0 category-encoders-2.6.1 dash-2.11.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 deprecated-1.2.14 deprecation-2.1.0 imbalanced-learn-0.11.0 importlib-metadata-6.8.0 joblib-1.3.2 kaleido-0.2.1 lightgbm-4.0.0 orjson-3.9.4 plotly-resampler-0.9.1 pmdarima-2.0.3 pycaret-3.0.4 pyod-1.1.0 retrying-1.3.4 schemdraw-0.15 scikit-base-0.5.0 scikit-plot-0.3.7 shap-0.42.1 sktime-0.21.0 slicer-0.0.7 tbats-1.1.3 trace-updater-0.0.9.1 tsdownsample-0.1.2 xxhash-3.3.0 yellowbrick-1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
from pycaret.classification import *

# %% [markdown]
# ## 2. Load Data

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object

# %% [markdown]
# ## Train and Evaluate Model

# %%
cat_features = ['sex', 'cp', 'fbs', 'restecg', 'exng', 'thall']

# %%
setup??

# %%
experment = setup(df, target='output', categorical_features=cat_features)
# Out:
# <style type="text/css">
# #T_bae97_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bae97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bae97_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bae97_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bae97_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bae97_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bae97_row0_col1" class="data row0 col1" >5632</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bae97_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bae97_row1_col1" class="data row1 col1" >output</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bae97_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_bae97_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bae97_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_bae97_row3_col1" class="data row3 col1" >(303, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bae97_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_bae97_row4_col1" class="data row4 col1" >(303, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bae97_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_bae97_row5_col1" class="data row5 col1" >(212, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bae97_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_bae97_row6_col1" class="data row6 col1" >(91, 22)</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bae97_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_bae97_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bae97_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_bae97_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bae97_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_bae97_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bae97_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_bae97_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bae97_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_bae97_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bae97_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_bae97_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bae97_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_bae97_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bae97_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_bae97_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_bae97_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_bae97_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_bae97_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_bae97_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_bae97_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_bae97_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_bae97_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_bae97_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_bae97_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_bae97_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_bae97_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_bae97_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_bae97_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_bae97_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_bae97_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_bae97_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_bae97_row22_col1" class="data row22 col1" >ce6e</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_79f3b th {
#   text-align: left;
# }
# #T_79f3b_row0_col0, #T_79f3b_row0_col2, #T_79f3b_row0_col3, #T_79f3b_row1_col0, #T_79f3b_row1_col1, #T_79f3b_row1_col2, #T_79f3b_row1_col3, #T_79f3b_row1_col4, #T_79f3b_row1_col5, #T_79f3b_row1_col6, #T_79f3b_row1_col7, #T_79f3b_row2_col0, #T_79f3b_row2_col1, #T_79f3b_row2_col2, #T_79f3b_row2_col3, #T_79f3b_row2_col4, #T_79f3b_row2_col5, #T_79f3b_row2_col6, #T_79f3b_row2_col7, #T_79f3b_row3_col0, #T_79f3b_row3_col1, #T_79f3b_row3_col2, #T_79f3b_row3_col3, #T_79f3b_row3_col4, #T_79f3b_row3_col5, #T_79f3b_row3_col6, #T_79f3b_row3_col7, #T_79f3b_row4_col0, #T_79f3b_row4_col1, #T_79f3b_row4_col2, #T_79f3b_row4_col3, #T_79f3b_row4_col4, #T_79f3b_row4_col5, #T_79f3b_row4_col6, #T_79f3b_row4_col7, #T_79f3b_row5_col0, #T_79f3b_row5_col1, #T_79f3b_row5_col3, #T_79f3b_row5_col4, #T_79f3b_row5_col5, #T_79f3b_row5_col6, #T_79f3b_row5_col7, #T_79f3b_row6_col0, #T_79f3b_row6_col1, #T_79f3b_row6_col2, #T_79f3b_row6_col3, #T_79f3b_row6_col4, #T_79f3b_row6_col5, #T_79f3b_row6_col6, #T_79f3b_row6_col7, #T_79f3b_row7_col0, #T_79f3b_row7_col1, #T_79f3b_row7_col2, #T_79f3b_row7_col3, #T_79f3b_row7_col4, #T_79f3b_row7_col5, #T_79f3b_row7_col6, #T_79f3b_row7_col7, #T_79f3b_row8_col0, #T_79f3b_row8_col1, #T_79f3b_row8_col2, #T_79f3b_row8_col3, #T_79f3b_row8_col4, #T_79f3b_row8_col5, #T_79f3b_row8_col6, #T_79f3b_row8_col7, #T_79f3b_row9_col0, #T_79f3b_row9_col1, #T_79f3b_row9_col2, #T_79f3b_row9_col3, #T_79f3b_row9_col4, #T_79f3b_row9_col5, #T_79f3b_row9_col6, #T_79f3b_row9_col7, #T_79f3b_row10_col0, #T_79f3b_row10_col1, #T_79f3b_row10_col2, #T_79f3b_row10_col3, #T_79f3b_row10_col4, #T_79f3b_row10_col5, #T_79f3b_row10_col6, #T_79f3b_row10_col7, #T_79f3b_row11_col0, #T_79f3b_row11_col1, #T_79f3b_row11_col2, #T_79f3b_row11_col3, #T_79f3b_row11_col4, #T_79f3b_row11_col5, #T_79f3b_row11_col6, #T_79f3b_row11_col7, #T_79f3b_row12_col0, #T_79f3b_row12_col1, #T_79f3b_row12_col2, #T_79f3b_row12_col3, #T_79f3b_row12_col4, #T_79f3b_row12_col5, #T_79f3b_row12_col6, #T_79f3b_row12_col7, #T_79f3b_row13_col0, #T_79f3b_row13_col1, #T_79f3b_row13_col2, #T_79f3b_row13_col4, #T_79f3b_row13_col5, #T_79f3b_row13_col6, #T_79f3b_row13_col7, #T_79f3b_row14_col0, #T_79f3b_row14_col1, #T_79f3b_row14_col2, #T_79f3b_row14_col3, #T_79f3b_row14_col4, #T_79f3b_row14_col5, #T_79f3b_row14_col6, #T_79f3b_row14_col7 {
#   text-align: left;
# }
# #T_79f3b_row0_col1, #T_79f3b_row0_col4, #T_79f3b_row0_col5, #T_79f3b_row0_col6, #T_79f3b_row0_col7, #T_79f3b_row5_col2, #T_79f3b_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_79f3b_row0_col8, #T_79f3b_row1_col8, #T_79f3b_row2_col8, #T_79f3b_row3_col8, #T_79f3b_row5_col8, #T_79f3b_row6_col8, #T_79f3b_row7_col8, #T_79f3b_row8_col8, #T_79f3b_row9_col8, #T_79f3b_row10_col8, #T_79f3b_row12_col8, #T_79f3b_row13_col8, #T_79f3b_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_79f3b_row4_col8, #T_79f3b_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_79f3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79f3b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_79f3b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_79f3b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_79f3b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_79f3b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_79f3b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_79f3b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_79f3b_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_79f3b_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79f3b_level0_row0" class="row_heading level0 row0" >nb</th>
#       <td id="T_79f3b_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_79f3b_row0_col1" class="data row0 col1" >0.8208</td>
#       <td id="T_79f3b_row0_col2" class="data row0 col2" >0.8674</td>
#       <td id="T_79f3b_row0_col3" class="data row0 col3" >0.8705</td>
#       <td id="T_79f3b_row0_col4" class="data row0 col4" >0.8297</td>
#       <td id="T_79f3b_row0_col5" class="data row0 col5" >0.8407</td>
#       <td id="T_79f3b_row0_col6" class="data row0 col6" >0.6336</td>
#       <td id="T_79f3b_row0_col7" class="data row0 col7" >0.6509</td>
#       <td id="T_79f3b_row0_col8" class="data row0 col8" >0.0350</td>
#     </tr>
#     <tr>
#       <th id="T_79f3b_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_79f3b_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_79f3b_row1_col1" class="data row1 col1" >0.8158</td>
#       <td id="T_79f3b_row1_col2" class="data row1 col2" >0.8842</td>
#       <td id="T_79f3b_row1_col3" class="data row1 col3" >0.8432</td>
#       <td id="T_79f3b_row1_col4" class="data row1 col4" >0.8265</td>
#       <td id="T_79f3b_row1_col5" class="data row1 col5" >0.8295</td>
#       <td id="T_79f3b_row1_col6" class="data row1 col6" >0.6279</td>
#       <td id="T_79f3b_row1_col7" class="data row1 col7" >0.6374</td>
#       <td id="T_79f3b_row1_col8" class="data row1 col8" >0.0930</td>
#     </tr>
#     <tr>
#       <th id="T_79f3b_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_79f3b_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_79f3b_row2_col1" class="data row2 col1" >0.7926</td>
#       <td id="T_79f3b_row2_col2" class="data row2 col2" >0.8686</td>
#       <td id="T_79f3b_row2_col3" class="data row2 col3" >0.8538</td>
#       <td id="T_79f3b_row2_col4" class="data row2 col4" >0.7853</td>
#       <td id="T_79f3b_row2_col5" class="data row2 col5" >0.8147</td>
#       <td id="T_79f3b_row2_col6" class="data row2 col6" >0.5801</td>
#       <td id="T_79f3b_row2_col7" class="data row2 col7" >0.5910</td>
#       <td id="T_79f3b_row2_col8" class="data row2 col8" >0.0860</td>
#     </tr>
#     <tr>
#       <th id="T_79f3b_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_79f3b_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_79f3b_row3_col1" class="data row3 col1" >0.7922</td>
#       <td id="T_79f3b_row3_col2" class="data row3 col2" >0.8842</td>
#       <td id="T_79f3b_row3_col3" class="data row3 col3" >0.8530</td>
#       <td id="T_79f3b_row3_col4" class="data row3 col4" >0.8012</td>
#       <td id="T_79f3b_row3_col5" class="data row3 col5" >0.8161</td>
#       <td id="T_79f3b_row3_col6" class="data row3 col6" >0.5777</td>
#       <td id="T_79f3b_row3_col7" class="data row3 col7" >0.5997</td>
#       <td id="T_79f3b_row3_col8" class="data row3 col8" >0.7870</td>
#     </tr>
#     <tr>
#       <th id="T_79f3b_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_79f3b_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_79f3b_row4_col1" class="data row4 col1" >0.7920</td>
#       <td id="T_79f3b_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_79f3b_row4_col3" class="data row4 col3" >0.8530</td>
#       <td id="T_79f3b_row4_col4" class="data row4 col4" >0.7965</td>
#       <td id="T_79f3b_row4_col5" class="data row4 col5" >0.8175</td>
#       <td id="T_79f3b_row4_col6" class="data row4 col6" >0.5770</td>
#       <td id="T_79f3b_row4_col7" class="data row4 col7" >0.5921</td>
#       <td id="T_79f3b_row4_col8" class="data row4 col8" >0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_79f3b_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_79f3b_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_79f3b_row5_col1" class="data row5 col1" >0.7920</td>
#       <td id="T_79f3b_row5_col2" class="data row5 col2" >0.8872</td>
#       <td id="T_79f3b_row5_col3" class="data row5 col3" >0.8530</td>
#       <td id="T_79f3b_row5_col4" class="data row5 col4" >0.7965</td>
#       <td id="T_79f3b_row5_col5" class="data row5 co
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %% [markdown]
# ## Test Model

# %%
predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_215bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_215bc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_215bc_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_215bc_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_215bc_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_215bc_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_215bc_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_215bc_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_215bc_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_215bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_215bc_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_215bc_row0_col1" class="data row0 col1" >0.8242</td>
#       <td id="T_215bc_row0_col2" class="data row0 col2" >0.8890</td>
#       <td id="T_215bc_row0_col3" class="data row0 col3" >0.8600</td>
#       <td id="T_215bc_row0_col4" class="data row0 col4" >0.8269</td>
#       <td id="T_215bc_row0_col5" class="data row0 col5" >0.8431</td>
#       <td id="T_215bc_row0_col6" class="data row0 col6" >0.6433</td>
#       <td id="T_215bc_row0_col7" class="data row0 col7" >0.6440</td>
#     </tr>
#   </tbody>
# </table>
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 160   56    1   1     120   240    0        1       169     0      0.0    0
# 179   57    1   0     150   276    0        0       112     1      0.6    1
# 126   47    1   0     112   204    0        1       143     0      0.1    2
# 158   58    1   1     125   220    0        1       144     0      0.4    1
# 95    53    1   0     142   226    0        0       111     1      0.0    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 293   67    1   2     152   212    0        0       150     0      0.8    1
# 59    57    0   0     128   303    0        0       159     0      0.0    2
# 115   37    0   2     120   215    0        1       170     0      0.0    2
# 147   60    0   3     150   240    0        1       171     0      0.9    2
# 206   59    1   0     110   239    0        0       142     1      1.2    1
#
#      caa  thall  output  prediction_label  prediction_score
# 160    0      2       1                 1            0.9999
# 179    1      1       0                 0            1.0000
# 126    0      2       1                 1            0.9814
# 158    4      3       1                 0            0.8970
# 95     0      3       1                 0            0.9997
# ..   ...    ...     ...               ...               ...
# 293    0      3       0                 1            0.7862
# 59     1      2       1                 1            0.9741
# 115    0      2       1                 1            1.0000
# 147    0      2       1                 1            1.0000
# 206    1      3       0                 0            0.9998
#
# [91 rows x 16 columns]
